# %% [markdown]
# # Get Data

# %%
from dataprep.getdata import SatMask

# %%
path = "/Users/stouzani/Desktop/Unstructured_ML/Cities_projects/Newark_project/Data/"
features_path = path + "Newark_Building_Footprints.geojson"
tiles_cover_path = path + "Newark_bldgs.csv"
zoom = 19
size = 512
url_map = "https://api.mapbox.com/v4/mapbox.satellite/{z}/{x}/{y}@2x.jpg?access_token=pk.eyJ1Ijoic3RvdXphbmkiLCJhIjoiY2pzMTRtMzEzMDh5bjN5bzg2eDQ0N3FhYiJ9.5KKMQV5Qgl2ETj36mn4UXg"
image_format = "jpg"
mask_format = "png"
sat_path = path + "images/"
num_workers = 10
rast_path = path + "masks/"

# %%
satmask = SatMask(url_mapbox = url_map, image_format = image_format, 
                  mask_format = mask_format, tiles_cover_path = tiles_cover_path, 
                  sat_path = sat_path, gis_path = features_path, masks_path = rast_path, 
                  zoom = zoom, size = size ,num_workers = num_workers)

# %%
satmask.tiles_cover()

# %%
satmask.mapbox_download()

# %%
colors  = ['denim', 'orange']
satmask.map_feature(colors)

# %% [markdown]
# # Post Processing

# %%
from postproc.postprocessing import *

# %%
probs_path = ['/Users/stouzani/Desktop/Unstructured_ML/Cities_projects/Newark_project/Data/probs/']
masks_path = '/Users/stouzani/Desktop/Unstructured_ML/Cities_projects/Newark_project/Data/masks_probs'

# %%
get_masks_from_probs(probs_path, masks_path, probs_threshold=0.85, num_workers=4)

# %% [markdown]
# # Get Polygons

# %%
from postproc.postprocessing import get_polygons
# %matplotlib inline

# %%
pred_masks_path = '/Users/stouzani/Desktop/Unstructured_ML/Cities_projects/Newark_project/Data/masks_probs'
polygons_path = '/Users/stouzani/Desktop/Unstructured_ML/Cities_projects/Newark_project/Data/masks_probs/poly_masks_probs8.geojson'

# %%
get_polygons(pred_masks_path,polygons_path)
# Out:
#   3%|2         | 335/12528 [00:01<00:40, 299.18mask/s]Warning: extracted feature is not valid, skipping
#   7%|6         | 843/12528 [00:02<00:35, 330.15mask/s]Warning: extracted feature is not valid, skipping
#   8%|7         | 952/12528 [00:03<00:34, 336.04mask/s]Warning: extracted feature is not valid, skipping
#   8%|7         | 988/12528 [00:03<00:33, 342.59mask/s]Warning: extracted feature is not valid, skipping
#  11%|#         | 1333/12528 [00:04<00:40, 274.83mask/s]Warning: extracted feature is not valid, skipping
#  11%|#1        | 1396/12528 [00:04<00:39, 283.56mask/s]Warning: extracted feature is not valid, skipping
#  12%|#2        | 1525/12528 [00:04<00:35, 309.14mask/s]Warning: extracted feature is not valid, skipping
#  13%|#2        | 1621/12528 [00:05<00:35, 310.49mask/s]Warning: extracted feature is not valid, skipping
# Warning: extracted feature is not valid, skipping
#  21%|##        | 2589/12528 [00:08<00:29, 337.49mask/s]Warning: extracted feature is not valid, skipping
#  22%|##1       | 2716/12528 [00:08<00:35, 277.62mask/s]Warning: extracted feature is not valid, skipping
#  23%|##2       | 2868/12528 [00:09<00:35, 269.27mask/s]Warning: extracted feature is not valid, skipping
#  25%|##5       | 3148/12528 [00:10<00:28, 324.36mask/s]Warning: extracted feature is not valid, skipping
#  26%|##5       | 3249/12528 [00:10<00:30, 299.61mask/s]Warning: extracted feature is not valid, skipping
#  27%|##6       | 3325/12528 [00:10<00:27, 333.34mask/s]Warning: extracted feature is not valid, skipping
#  27%|##7       | 3393/12528 [00:10<00:29, 305.05mask/s]Warning: extracted feature is not valid, skipping
#  28%|##7       | 3488/12528 [00:11<00:30, 292.96mask/s]Warning: extracted feature is not valid, skipping
#  31%|###       | 3838/12528 [00:12<00:29, 295.82mask/s]Warning: extracted feature is not valid, skipping
#  36%|###6      | 4516/12528 [00:14<00:24, 329.09mask/s]Warning: extracted feature is not valid, skipping
#  39%|###8      | 4834/12528 [00:15<00:24, 314.03mask/s]Warning: extracted feature is not valid, skipping
#  42%|####1     | 5250/12528 [00:16<00:23, 313.39mask/s]Warning: extracted feature is not valid, skipping
#  93%|#########3| 11694/12528 [00:37<00:03, 273.63mask/s]Warning: extracted feature is not valid, skipping
#  94%|#########3| 11726/12528 [00:37<00:02, 285.14mask/s]Warning: extracted feature is not valid, skipping
#  96%|#########5| 12020/12528 [00:38<00:01, 301.83mask/s]Warning: extracted feature is not valid, skipping
#  98%|#########8| 12285/12528 [00:38<00:00, 329.23mask/s]Warning: extracted feature is not valid, skipping
#  99%|#########8| 12389/12528 [00:39<00:00, 314.14mask/s]Warning: extracted feature is not valid, skipping
# 100%|##########| 12528/12528 [00:39<00:00, 315.06mask/s]

# %%
import geopandas as gpd
gdf_newark = gpd.read_file(polygons_path)

# %%
gdf_newark.shape
# Out:
# (65392, 1)

# %%
gdf_newark.plot(figsize=(18, 16))

# %% [markdown]
# # Merge Polygons

# %%
from postproc.postprocessing import merge_polygons
# %matplotlib inline

# %%
polygons_path = '/Users/stouzani/Desktop/Unstructured_ML/Cities_projects/Newark_project/Data/poly_masks_probs8.geojson'
new_polygons_path = '/Users/stouzani/Desktop/Unstructured_ML/Cities_projects/Newark_project/Data/poly_masks_merged.geojson'

# %%
merge_polygons(polygons_path,new_polygons_path,.25)
# Out:
# Building graph: 100%|##########| 65392/65392 [2:14:34<00:00,  6.63shapes/s]
# Merging components: 100%|##########| 55254/55254 [5:25:28<00:00,  3.28component/s]

# %%
# import pyproj
# print (pyproj.__version__)
# Out:
# 2.4.2.post1

# %%
import geopandas as gpd
gdf_newark_merged = gpd.read_file(new_polygons_path)
gdf_newark_merged.shape
# Out:
# (55254, 2)

# %%
gdf_newark_merged.plot(figsize=(18, 16))

# %%
gdf_newark_merged['geometry'] = [gpd.GeoSeries(x).scale(xfact=1.04, yfact=1.04)[0] for x in gdf_newark_merged['geometry']]

# %%
gdf_newark_merged.plot(figsize=(18, 16))

# %% [markdown]
# # Analysis with a smaller area of Newark

# %%
polygons_path = '/Users/stouzani/Desktop/Unstructured_ML/Cities_projects/Newark_project/Data/poly_masks_probs8.geojson'
#new_polygons_path = '/Users/stouzani/Desktop/Unstructured_ML/Cities_projects/Newark_project/Data/poly_masks_merged.geojson'

# %%
import geopandas as gpd
from postproc.postprocessing import merge_polygons
# %matplotlib inline

# %%
gdf_newark = gpd.read_file(polygons_path)
gdf_newark.shape
# Out:
# (65392, 1)

# %%
gdf_newark.geom_type.unique()
# Out:
# array(['Polygon'], dtype=object)

# %%
gdf_newark_small = gdf_newark.cx[-74.2:-74.185, 40.73:40.75]

# %%
gdf_newark_small.shape
# Out:
# (3621, 1)

# %%
gdf_newark_small.plot(figsize=(18, 16))

# %%
gdf_newark_small.to_file(driver = 'GeoJSON', filename= '/Users/stouzani/Desktop/Unstructured_ML/Cities_projects/Newark_project/Data/small_poly_masks_probs8.geojson')
# Out:
# /anaconda3/envs/GIS/lib/python3.7/site-packages/geopandas/io/file.py:108: FionaDeprecationWarning: Use fiona.Env() instead.
#   with fiona.drivers():

# %%
small_polygons_path = '/Users/stouzani/Desktop/Unstructured_ML/Cities_projects/Newark_project/Data/small_poly_masks_probs8.geojson'
small_new_polygons_path = '/Users/stouzani/Desktop/Unstructured_ML/Cities_projects/Newark_project/Data/small_poly_masks_merged.geojson'

# %%
merge_polygons(small_polygons_path,small_new_polygons_path,.45)
# Out:
# Building graph: 100%|##########| 3621/3621 [07:26<00:00,  8.11shapes/s]
# Merging components: 100%|##########| 2587/2587 [17:27<00:00,  2.78component/s]

# %%
gdf_newark_merged_small = gpd.read_file(small_new_polygons_path)
gdf_newark_merged_small.shape
# Out:
# (2587, 2)

# %%
gdf_newark_merged_small.plot(figsize=(18, 16))

# %%
small_new_polygons_path = '/Users/stouzani/Desktop/Unstructured_ML/Cities_projects/Newark_project/Data/small_poly_masks_merged_0_55.geojson'
#merge_polygons(small_polygons_path,small_new_polygons_path,.75)

# %%
import os
root_dir = '/Users/stouzani/Desktop/Unstructured_ML/Cities_projects/SF_test/prediction/diecewce/probs/'
mage_paths = list(os.listdir(root_dir))#list(map(lambda x: os.path.join(root_dir, 'images', x),os.listdir((root_dir))))

# %%
mage_paths[0:5]
# Out:
# ['19_83817_202588.png',
#  '19_83799_202755.png',
#  '19_83828_202767.png',
#  '19_83834_202606.png',
#  '19_83805_202745.png']
